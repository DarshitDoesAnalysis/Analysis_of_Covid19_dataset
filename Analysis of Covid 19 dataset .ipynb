# %% [markdown]
# # **Analysis of Covid-19 dataset**

# %%
# importing required libraries

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r'/content/Covid data analysis.csv')
data
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [321 rows x 6 columns]

# %%
data.count()
# Out:
# Date         321
# State        140
# Region       321
# Confirmed    321
# Deaths       321
# Recovered    321
# dtype: int64

# %%
data.isnull().sum()
# Out:
# Date           0
# State        181
# Region         0
# Confirmed      0
# Deaths         0
# Recovered      0
# dtype: int64

# %% [markdown]
# # **Show the numbers of confirmed, Deaths and recovered cases in each region**

# %%
data.head(4)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455
# 2  4/29/2020   NaN      Algeria       3848     444       1702
# 3  4/29/2020   NaN      Andorra        743      42        423

# %%
data.groupby(['Region']).sum()
# Out:
# <ipython-input-19-d64317881ef9>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby(['Region']).sum()
#                     Confirmed  Deaths  Recovered
# Region
# Afghanistan              1939      60        252
# Albania                   766      30        455
# Algeria                  3848     444       1702
# Andorra                   743      42        423
# Angola                     27       2          7
# ...                       ...     ...        ...
# West Bank and Gaza        344       2         71
# Western Sahara              6       0          5
# Yemen                       6       0          1
# Zambia                     97       3         54
# Zimbabwe                   32       4          5
#
# [187 rows x 3 columns]

# %%
data.groupby(['Region'])['Confirmed'].sum()
# Out:
# Region
# Afghanistan           1939
# Albania                766
# Algeria               3848
# Andorra                743
# Angola                  27
#                       ...
# West Bank and Gaza     344
# Western Sahara           6
# Yemen                    6
# Zambia                  97
# Zimbabwe                32
# Name: Confirmed, Length: 187, dtype: int64

# %%
# sorting with numbers

data.groupby(['Region'])['Confirmed'].sum().sort_values(ascending=False).head(10)
# Out:
# Region
# US                1039909
# Spain              236899
# Italy              203591
# France             166543
# UK                 166441
# Germany            161539
# Turkey             117589
# Russia              99399
# Iran                93657
# Mainland China      82862
# Name: Confirmed, dtype: int64

# %%
data.groupby(['Region'])['Confirmed','Deaths'].sum().sort_values(by='Confirmed', ascending=False).head(10)
# Out:
# <ipython-input-35-a5ba1f64abf8>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data.groupby(['Region'])['Confirmed','Deaths'].sum().sort_values(by='Confirmed', ascending=False).head(10)
#                 Confirmed  Deaths
# Region
# US                1039909   60967
# Spain              236899   24275
# Italy              203591   27682
# France             166543   24121
# UK                 166441   26166
# Germany            161539    6467
# Turkey             117589    3081
# Russia              99399     972
# Iran                93657    5957
# Mainland China      82862    4633

# %% [markdown]
# # **Remove all the recorders where confirmed cases is less than 10**

# %%
data.head()
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455
# 2  4/29/2020   NaN      Algeria       3848     444       1702
# 3  4/29/2020   NaN      Andorra        743      42        423
# 4  4/29/2020   NaN       Angola         27       2          7

# %%
data = data[~(data['Confirmed'] < 10)]
data
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [304 rows x 6 columns]

# %% [markdown]
# # **In which region, maximum number of confirmed cases were recorded ?**

# %%
data.head()
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455
# 2  4/29/2020   NaN      Algeria       3848     444       1702
# 3  4/29/2020   NaN      Andorra        743      42        423
# 4  4/29/2020   NaN       Angola         27       2          7

# %%
# Maximum confirmed cases are recorded

data.groupby('Region')['Confirmed'].sum().sort_values(ascending=False).head(10)
# Out:
# Region
# US                1039909
# Spain              236899
# Italy              203591
# France             166536
# UK                 166432
# Germany            161539
# Turkey             117589
# Russia              99399
# Iran                93657
# Mainland China      82861
# Name: Confirmed, dtype: int64

# %%
# Minimum confirmed cases are recorded

data.groupby('Region')['Confirmed'].sum().sort_values(ascending=True).head(10)
# Out:
# Region
# Suriname                            10
# Gambia                              10
# Holy See                            10
# Burundi                             11
# Seychelles                          11
# Nicaragua                           13
# Saint Kitts and Nevis               15
# Dominica                            16
# Namibia                             16
# Saint Vincent and the Grenadines    16
# Name: Confirmed, dtype: int64

# %% [markdown]
# # **In which region, minimum number of deaths cases were recorded ?**

# %%
data.groupby('Region')['Deaths'].sum().sort_values(ascending=True).head(10)
# Out:
# Region
# Cambodia                    0
# Seychelles                  0
# Saint Lucia                 0
# Central African Republic    0
# Saint Kitts and Nevis       0
# South Sudan                 0
# Rwanda                      0
# Grenada                     0
# Macau                       0
# Madagascar                  0
# Name: Deaths, dtype: int64

# %% [markdown]
# # **How many confirmed, deaths and recovered cases were reported in India till 29 April 2020 ?**

# %%
data.head()
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455
# 2  4/29/2020   NaN      Algeria       3848     444       1702
# 3  4/29/2020   NaN      Andorra        743      42        423
# 4  4/29/2020   NaN       Angola         27       2          7

# %%
data.dtypes
# Out:
# Date         object
# State        object
# Region       object
# Confirmed     int64
# Deaths        int64
# Recovered     int64
# dtype: object

# %%
# Converting Date column into datetime format

data['Date'] = pd.to_datetime(data['Date'])

# %%
data.dtypes
# Out:
# Date         datetime64[ns]
# State                object
# Region               object
# Confirmed             int64
# Deaths                int64
# Recovered             int64
# dtype: object

# %%
data.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0 2020-04-29   NaN  Afghanistan       1939      60        252
# 1 2020-04-29   NaN      Albania        766      30        455

# %%
data[data['Region'] == 'India']
# Out:
#          Date State Region  Confirmed  Deaths  Recovered
# 74 2020-04-29   NaN  India      33062    1079       8437

# %% [markdown]
# # **Sort the entire data by confirmed cases in ascending order**

# %%
data.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0 2020-04-29   NaN  Afghanistan       1939      60        252
# 1 2020-04-29   NaN      Albania        766      30        455

# %%
data.sort_values(by='Confirmed', ascending=True).head(20)
# Out:
#           Date                        State                            Region  \
# 156 2020-04-29                          NaN                          Suriname
# 70  2020-04-29                          NaN                          Holy See
# 59  2020-04-29                          NaN                            Gambia
# 318 2020-04-29                        Yukon                            Canada
# 217 2020-04-29                    Greenland                           Denmark
# 256 2020-04-29                   Montserrat                                UK
# 144 2020-04-29                          NaN                        Seychelles
# 27  2020-04-29                          NaN                           Burundi
# 306 2020-04-29     Turks and Caicos Islands                                UK
# 118 2020-04-29                          NaN                         Nicaragua
# 215 2020-04-29               Grand Princess                            Canada
# 206 2020-04-29  Falkland Islands (Malvinas)                                UK
# 270 2020-04-29     Northern Mariana Islands                                US
# 136 2020-04-29                          NaN             Saint Kitts and Nevis
# 138 2020-04-29                          NaN  Saint Vincent and the Grenadines
# 45  2020-04-29                          NaN                          Dominica
# 201 2020-04-29                      Curacao                       Netherlands
# 114 2020-04-29                          NaN                           Namibia
# 137 2020-04-29                          NaN                       Saint Lucia
# 260 2020-04-29                New Caledonia                            France
#
#      Confirmed  Deaths  Recovered
# 156         10       1          8
# 70          10       0          2
# 59          10       1          8
# 318         11       0          0
# 217         11       0         11
# 256         11       1          2
# 144         11       0          6
# 27          11       1          4
# 306         12       1          5
# 118         13       3          7
# 215         13       0          0
# 206         13       0         11
# 270         14       2          0
# 136         15       0          4
# 138         16       0          8
# 45          16       0         13
# 201         16       1         13
# 114         16       0          8
# 137         17       0         15
# 260         18       0         17

# %% [markdown]
# # **Sort the entire data by recovered cases in ascending order**

# %%
data.sort_values(by='Recovered', ascending=False).head(20)
# Out:
#           Date  State          Region  Confirmed  Deaths  Recovered
# 153 2020-04-29    NaN           Spain     236899   24275     132929
# 61  2020-04-29    NaN         Germany     161539    6467     120400
# 76  2020-04-29    NaN            Iran      93657    5957      73791
# 80  2020-04-29    NaN           Italy     203591   27682      71252
# 229 2020-04-29  Hubei  Mainland China      68128    4512      63616
# 57  2020-04-29    NaN          France     165093   24087      48228
# 167 2020-04-29    NaN          Turkey     117589    3081      44040
# 22  2020-04-29    NaN          Brazil      79685    5513      34132
# 158 2020-04-29    NaN     Switzerland      29407    1716      22600
# 78  2020-04-29    NaN         Ireland      20253    1190      13386
# 8   2020-04-29    NaN         Austria      15402     580      12779
# 107 2020-04-29    NaN          Mexico      17799    1732      11423
# 15  2020-04-29    NaN         Belgium      47859    7501      11283
# 134 2020-04-29    NaN          Russia      99399     972      10286
# 128 2020-04-29    NaN            Peru      33931     943      10037
# 151 2020-04-29    NaN     South Korea      10765     247       9059
# 74  2020-04-29    NaN           India      33062    1079       8437
# 79  2020-04-29    NaN          Israel      15834     215       8233
# 33  2020-04-29    NaN           Chile      14885     216       8057
# 42  2020-04-29    NaN         Denmark       9008     443       6366
